# %%
from openai import OpenAI
import os 
client = OpenAI(api_key=os.environ.get("CUSTOM_ENV_NAME", "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"))

response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Who won the world series in 2020?"},
    {"role": "assistant", "content": "The Los Angeles Dodgers won the World Series in 2020."},
    {"role": "user", "content": "Where was it played?"}
  ]
)
print(response.choices[0].message.content)
# Out:
# The 2020 World Series was played at Globe Life Field in Arlington, Texas.

# %%
import PyPDF2
# import openai

# Set your OpenAI API key here
# openai.api_key = "YOUR_API_KEY"

def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        for page_num in range(len(reader.pages)):
            page = reader.pages[page_num]
            text += page.extract_text()
    return text

pdf_path = r"/home/vuthede/Downloads/Alcolizer-White-Paper-The-Use-Of-Fuel-Cell-Technology-in-Breathalysers-v1.pdf"
text = extract_text_from_pdf(pdf_path)
print(text)
# Out:
# THE USE OF
# FUEL CELL
# TECHNOLOGY IN
# BREATHALYSERSABSTRACT
# Fuel cell technology the heart of
# modern breathalysers, how and
# why they work is a direct result
# of individual fuel cell design and
# manufactured quality. Superior
# fuel cell instruments deliver “law
# enforcement quality” while cheaper alternatives mean owners are likely
# to pay a higher price in maintaining
# a lower accuracy instrument with a
# significantly shorter operational life.
#
# By Laddie Nadilo
# WHITE  PAPER  SERIESRESEARCH    DESIGN  & DEvELOPmENT   mANUFACTURING
# SALES  & SERvICE   CALIBRATION  & REPAIR   TRAINING  & EDUCATIONWhite PaPer Serie S:
# the use of Fuel Cell t echnology in Breathalysers INTRODUCTION
# a breathalyser is a device
# for measuring blood alcohol
# concentration (BAC) from a breath
# sample. Breath analysers do not
# directly measure blood alcohol
# concentration, which requires the
# analysis of a blood sample. Instead,
# they estimate BAC indirectly by
# ...

# %% [markdown]
# ### Input:  pdf + Question about pdf
# ### Output: respone

# %%
from openai import OpenAI
import openai
import os 
client = OpenAI(api_key=os.environ.get("CUSTOM_ENV_NAME", "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"))
# Set your OpenAI API key here
# openai.api_key = "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"
# openai.api_key = "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" 
def ask_user_manual(question, manual_text):
    # Generate a completion using the OpenAI API
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": manual_text},
            {"role": "user", "content": "Question: " + question}
        ]
    )
    
    # Extract the answer from the completion
    answer = response.choices[0].message.content
    return answer

# Example usage
if _name_ == "_main_":
    user_manual_text = """
    User Manual
    
    Welcome to the User Manual. This manual will guide you through the setup and usage of our product.
    
    Section 1: Getting Started
    To begin, plug in the device and turn it on.
    
    Section 2: Setup
    Follow the on-screen instructions to complete the setup process.
    
    Section 3: Usage
    Once setup is complete, you can start using the product. Press the 'Start' button to begin.
    
    """
    
    question = "How do I start using the product?"
    answer = ask_user_manual(question, user_manual_text)
    print("Question:", question)
    print("Answer:", answer)

# %%
import openai 

def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        for page_num in range(len(reader.pages)):
            page = reader.pages[page_num]
            text += page.extract_text()
    return text



client = OpenAI(api_key=os.environ.get("CUSTOM_ENV_NAME", "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"))

response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Who won the world series in 2020?"},
    {"role": "assistant", "content": "The Los Angeles Dodgers won the World Series in 2020."},
    {"role": "user", "content": "Where was it played?"}
  ]
)

def generate_response():
    # Get prompt and PDF file path from the request
    prompt = 'What is the main content of that file pdf'
    pdf_path = '/home/vuthede/Downloads/Alcolizer-White-Paper-The-Use-Of-Fuel-Cell-Technology-in-Breathalysers-v1.pdf'

    # Read the contents of the PDF file
    pdf_content = extract_text_from_pdf(pdf_path)
    
    # Construct the prompt
    prompt_with_pdf = f"{prompt}\n\nPDF Content:\n{pdf_content}"
    # # Set up parameters for the OpenAI API call

    # # Call the OpenAI API to generate a response
    parameters = {
        model="gpt-3.5-turbo",
        "messages": [
            {
                "role": "system",
                "content": "You are a helpful assistant."
            },
            {
                "role": "user",
                "content": prompt_with_pdf
            }
        ]
    }
    response = client.chat.completions.create(**parameters)

    # # Get the generated response
    generated_text = response.choices[0].text.strip()

    # # Return the generated response
    print(generated_text)
generate_response()
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /tmp/ipykernel_7710/71564078.py in <module>
#      57     # # Return the generated response
#      58     print(generated_text)
# ---> 59 generate_response()
#
# /tmp/ipykernel_7710/71564078.py in generate_response()
#      50         ]
#      51     }
# ---> 52     response = client.chat.completions.create(**parameters)
#      53
#      54     # # Get the generated response
#
# ~/anaconda3/envs/dms/lib/python3.7/site-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     273                         msg = f"Missing required argument: {quote(missing[0])}"
#     274                 raise TypeError(msg)
# --> 275             return func(*args, **kwargs)
#     276
#     277         return wrapper  # type: ignore
#
# ...
